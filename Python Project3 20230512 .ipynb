# %%
#Introduction: Python Project3 - NYPD Open Source Data

# %%
# - Business Question:

# %%
#First, import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
#Import Data

# %%
df = pd.read_csv("https://data.cityofnewyork.us/api/views/uip8-fykc/rows.csv?accessType=DOWNLOAD")

# %%
#Quick Glance in what data looks like

# %%
df.head(20)
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0    263187871  02/07/2023  105.0               STRANGULATION 1ST  106.0
# 1    261368273  01/04/2023    NaN                          (null)    NaN
# 2    261667175  01/10/2023  101.0                       ASSAULT 3  344.0
# 3    264298625  02/27/2023    NaN                          (null)    NaN
# 4    261516485  01/07/2023  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 5    261273897  01/03/2023  101.0                       ASSAULT 3  344.0
# 6    261487453  01/06/2023  244.0   BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 7    262291240  01/21/2023  101.0                       ASSAULT 3  344.0
# 8    261927480  01/14/2023  101.0                       ASSAULT 3  344.0
# 9    261823038  01/12/2023  105.0               STRANGULATION 1ST  106.0
# 10   263870161  02/19/2023    NaN                          (null)    NaN
# 11   262219079  01/20/2023  244.0   BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# ...

# %%
#Get description of Dataset

# %%
df.describe()
# Out:
#          ARREST_KEY         PD_CD         KY_CD  ARREST_PRECINCT  \
# count  5.457600e+04  54325.000000  54325.000000     54576.000000
# mean   2.635819e+08    430.457174    251.346618        63.581849
# std    1.401601e+06    277.973670    149.381441        34.536247
# min    2.611809e+08     12.000000    101.000000         1.000000
# 25%    2.623376e+08    115.000000    113.000000        40.000000
# 50%    2.635892e+08    397.000000    236.000000        63.000000
# 75%    2.647476e+08    705.000000    344.000000       101.000000
# max    2.660041e+08    972.000000    995.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD      Latitude  \
# count       54576.000000  5.457600e+04   54576.000000  54576.000000
# mean            0.967147  1.005843e+06  208315.449337     40.737667
# std             7.865097  2.176083e+04   29773.620121      0.192568
# min             0.000000  0.000000e+00       0.000000      0.000000
# ...

# %%
#Check dataframe Column types

# %%
df.dtypes
# Out:
# ARREST_KEY                    int64
# ARREST_DATE                  object
# PD_CD                       float64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE             int64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                    int64
# Y_COORD_CD                    int64
# Latitude                    float64
# Longitude                   float64
# New Georeferenced Column     object
# dtype: object

# %%
#Drop n/a values

# %%
df1 = df.dropna(how='any',axis=0)

# %%
#Checking how many unique values are in each column

# %%
df1.nunique()
# Out:
# ARREST_KEY                  53905
# ARREST_DATE                    90
# PD_CD                         211
# PD_DESC                       202
# KY_CD                          63
# OFNS_DESC                      59
# LAW_CODE                      727
# LAW_CAT_CD                      5
# ARREST_BORO                     5
# ARREST_PRECINCT                77
# JURISDICTION_CODE              18
# AGE_GROUP                       5
# PERP_SEX                        3
# PERP_RACE                       7
# X_COORD_CD                  14700
# Y_COORD_CD                  15112
# Latitude                    16192
# Longitude                   16204
# New Georeferenced Column    16408
# dtype: int64

# %%
df1.describe()
# Out:
#          ARREST_KEY         PD_CD         KY_CD  ARREST_PRECINCT  \
# count  5.390500e+04  53905.000000  53905.000000     53905.000000
# mean   2.635811e+08    433.460625    245.552453        63.656284
# std    1.402096e+06    276.954369    134.707762        34.405814
# min    2.611809e+08    100.000000    101.000000         1.000000
# 25%    2.623301e+08    129.000000    113.000000        40.000000
# 50%    2.635892e+08    397.000000    236.000000        63.000000
# 75%    2.647556e+08    705.000000    344.000000       100.000000
# max    2.660041e+08    972.000000    881.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD      Latitude  \
# count       53905.000000  5.390500e+04   53905.000000  53905.000000
# mean            0.951971  1.005780e+06  208297.854151     40.737610
# std             7.790696  2.172484e+04   29848.560060      0.193635
# min             0.000000  0.000000e+00       0.000000      0.000000
# ...

# %%
df1.isnull()
# Out:
#        ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# 0           False        False  False    False  False      False     False
# 2           False        False  False    False  False      False     False
# 4           False        False  False    False  False      False     False
# 5           False        False  False    False  False      False     False
# 6           False        False  False    False  False      False     False
# ...           ...          ...    ...      ...    ...        ...       ...
# 54571       False        False  False    False  False      False     False
# 54572       False        False  False    False  False      False     False
# 54573       False        False  False    False  False      False     False
# 54574       False        False  False    False  False      False     False
# 54575       False        False  False    False  False      False     False
#
# ...

# %%
#Note "ARREST_BORO" has both K-Kings and B-Brooklyn, Let's fix this to improve comparisons

# %%
df2 = df1.replace('K', 'B')

# %%
df2.tail(20)
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  \
# 54556   265984380  03/31/2023  339.0
# 54557   265414752  03/21/2023  478.0
# 54558   265156804  03/15/2023  968.0
# 54559   265228364  03/16/2023  922.0
# 54560   264853462  03/10/2023  397.0
# 54561   265698722  03/27/2023  922.0
# 54562   265891025  03/30/2023  101.0
# 54563   265205613  03/16/2023  681.0
# 54564   265584581  03/24/2023  397.0
# 54565   265808105  03/29/2023  205.0
# 54566   265115010  03/15/2023  397.0
# 54567   265546491  03/23/2023  114.0
# 54568   265763687  03/28/2023  289.0
# 54569   265792485  03/28/2023  109.0
# 54570   265798114  03/28/2023  817.0
# 54571   265375648  03/20/2023  105.0
# 54572   265375611  03/20/2023  113.0
# 54573   265027445  03/13/2023  439.0
# 54574   265277526  03/17/2023  101.0
# 54575   265989716  03/31/2023  792.0
#
#                                          PD_DESC  KY_CD  \
# 54556             LARCENY,PETIT FROM OPEN AREAS,  341.0
# ...

# %%
#Compare Race to Precinct to see if one race is more likely to b arrest in particular pa

# %%
chart = sns.boxplot(y=df1['ARREST_PRECINCT'], x=df1['PERP_RACE'])
plt.figure(figsize=(30, 10))
chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation= -20, 
    horizontalalignment='left')
# Out:
# [Text(0, 0, 'BLACK'),
#  Text(1, 0, 'WHITE HISPANIC'),
#  Text(2, 0, 'WHITE'),
#  Text(3, 0, 'UNKNOWN'),
#  Text(4, 0, 'BLACK HISPANIC'),
#  Text(5, 0, 'ASIAN / PACIFIC ISLANDER'),
#  Text(6, 0, 'AMERICAN INDIAN/ALASKAN NATIVE')]

# %%
plt.scatter(x = df1['ARREST_DATE'], y = df1['ARREST_PRECINCT'])

# %%
plt.plot(x= df1['ARREST_BORO'], y = df1['PERP_RACE'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23700\1368332838.py in <module>
# ----> 1 plt.plot(x= df1['ARREST_BORO'], y = df1['PERP_RACE'])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
# ...

# %%
fig = plt.figure()
